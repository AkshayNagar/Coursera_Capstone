# %% [markdown]
# # Battle of Neighborhood

# %% [markdown]
# ## Code Notebook

# %% [markdown]
# ## Approach

# %% [markdown]
# I will be using above data to feed into KMeans Clustering algorithm. This will cluster all restaurants into 4 different clusters. Then I will assign each restaurant to a cluster. Later I will examine each cluster to get the cluster characteristics. This might sound a bit difficult , but trust me its fun.
#
# Let's just divide the whole process in following steps so it will be easy to follow:
#     1. Importing all required libraries.
#     2. Gathering Data using FourSquare API.
#     3. Creating Clusters.
#     4. Examine Clusters.

# %% [markdown]
# ### 1. Importing all required libraries

# %%
import numpy as np
import pandas as pd

import json

import folium

from geopy.geocoders import Nominatim

from pandas.io.json import json_normalize

import requests

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

#import beautiful soup
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ### 2. Gathering Data using FourSquare API

# %%
city = 'Newyork , NY'

geolocator = Nominatim()
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of NewYork')
print('Latitude : {} , Longitude : {}'.format(latitude, longitude))
# Out:
# C:\Users\akshay.nagar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# The geograpical coordinate of NewYork
# Latitude : 40.83975585 , Longitude : -73.9414480148711

# %%
## Let's define our credential to access Foursquare APIs.

CLIENT_ID = '45HRKK0U5TSXEPTKMAQFKQ43FMT05PERYFZCMBNHOEGIJ2VW'
CLIENT_SECRET = 'THF5OEHLXZNXOCYAOFT5IRO0ZCCONFDHE4KZQ403EYOHP2A5'
VERSION = '20191015'

# %%
## Now we have NY City geographic location we can pull places/venues using Foursquare API.

LIMIT = 300 # limit the number of venues returned.
radius = 1000 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
print(url)
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=45HRKK0U5TSXEPTKMAQFKQ43FMT05PERYFZCMBNHOEGIJ2VW&client_secret=THF5OEHLXZNXOCYAOFT5IRO0ZCCONFDHE4KZQ403EYOHP2A5&v=20191015&ll=40.83975585,-73.9414480148711&radius=1000&limit=300

# %%
## Let's pull json file of the venues using above url.

venues_json = requests.get(url).json()
venues_json
# Out:
# {'meta': {'code': 200, 'requestId': '5da9a2cf48b1e1002b061522'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Washington Heights',
#   'headerFullLocation': 'Washington Heights, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 108,
#   'suggestedBounds': {'ne': {'lat': 40.848755859000015,
#     'lng': -73.92957397340597},
#    'sw': {'lat': 40.83075584099999, 'lng': -73.95332205633623}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac93103f964a52013bf20e3',
#        'name': 'Highbridge Park',
#        'location': {'address': '173rd St & Amsterdam Ave',
#         'crossStreet': 'at Amsterdam Ave',
#         'lat': 40.84076848482368,
#         'lng': -73.94292688638392,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84076848482368,
#           'lng': -73.94292688638392}],
#         'distance': 167,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['173rd St & Amsterdam Ave (at Amsterdam Ave)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac93103f964a52013bf20e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2ce776f964a5208fca24e3',
#        'name': 'Carrot Top Pastries',
#        'location': {'address': '3931 Broadway',
#         'crossStreet': 'btwn 165th & 166th St.',
#         'lat': 40.838932749916395,
#         'lng': -73.94135949479988,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.838932749916395,
#           'lng': -73.94135949479988}],
#         'distance': 91,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3931 Broadway (btwn 165th & 166th St.)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '93685671'}},
#       'referralId': 'e-0-4b2ce776f964a5208fca24e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b68d051f964a520518e2be3',
#        'name': 'Las Palmas',
#        'location': {'address': '3891 Broadway',
#         'crossStreet': 'btwn W 162nd & W 163rd St',
#         'lat': 40.83757537476235,
#         'lng': -73.9423507444746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83757537476235,
#           'lng': -73.9423507444746}],
#         'distance': 254,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3891 Broadway (btwn W 162nd & W 163rd St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b68d051f964a520518e2be3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506cc066e4b019e8dad3a401',
#        'name': 'Columbia Wine Company',
#        'location': {'address': '4038 Broadway',
#         'crossStreet': 'at W 170th St',
#         'lat': 40.8420756,
#         'lng': -73.93880089999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8420756,
#           'lng': -73.93880089999999}],
#         'distance': 341,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4038 Broadway (at W 170th St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d119951735',
#          'name': 'Wine Shop',
#          'pluralName': 'Wine Shops',
#          'shortName': 'Wine Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61434648'}},
#       'referralId': 'e-0-506cc066e4b019e8dad3a401-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfe3f6bd4c01dccaebd615a',
#        'name': 'Word Up: Community Bookshop/Libreria',
#        'location': {'address': '2113 Amsterdam Ave',
#         'crossStreet': '165 street',
#         'lat': 40.837838645597536,
#         'lng': -73.93829239636327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.837838645597536,
#           'lng': -73.93829239636327}],
#         'distance': 340,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['2113 Amsterdam Ave (165 street)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '67620120'}},
#       'referralId': 'e-0-4dfe3f6bd4c01dccaebd615a-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b0144f964a5205fde28e3',
#        'name': 'New Balance Track & Field Center at The Armory',
#        'location': {'address': '216 Fort Washington Ave',
#         'crossStreet': 'near 168th & Broadway',
#         'lat': 40.84237921810222,
#         'lng': -73.94187469369459,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84237921810222,
#           'lng': -73.94187469369459}],
#         'distance': 294,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['216 Fort Washington Ave (near 168th & Broadway)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d106941735',
#          'name': 'Track',
#          'pluralName': 'Tracks',
#          'shortName': 'Track',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_track_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '433098152'}},
#       'referralId': 'e-0-4b5b0144f964a5205fde28e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e416857d164f2d277c2922a',
#        'name': 'Fort Washington Greenmarket Farmers Market',
#        'location': {'address': 'Fort Washington Avenue',
#         'crossStreet': 'Btwn 168th & 169th Streets',
#         'lat': 40.84261268539106,
#         'lng': -73.94206523895264,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84261268539106,
#           'lng': -73.94206523895264}],
#         'distance': 322,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Fort Washington Avenue (Btwn 168th & 169th Streets)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e416857d164f2d277c2922a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af0c188f964a520e2de21e3',
#        'name': 'Tasty Deli',
#        'location': {'address': '4020 Broadway',
#         'crossStreet': 'W 169th St',
#         'lat': 40.84181825314834,
#         'lng': -73.93929550503071,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84181825314834,
#           'lng': -73.93929550503071}],
#         'distance': 292,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4020 Broadway (W 169th St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '258418',
#         'url': 'https://www.seamless.com/menu/tasty-deli-4020-broadway-ave-new-york/258418?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=258418',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af0c188f964a520e2de21e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53f045ba498ec9e735cd769d',
#        'name': 'Rain II',
#        'location': {'address': '1095 Saint Nicholas Ave',
#         'crossStreet': '165',
#         'lat': 40.838368270850744,
#         'lng': -73.93989989565722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.838368270850744,
#           'lng': -73.93989989565722}],
#         'distance': 202,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1095 Saint Nicholas Ave (165)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '295360',
#         'url': 'https://www.seamless.com/menu/rain-ii-1095-st-nicholas-ave-new-york/295360?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=295360',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53f045ba498ec9e735cd769d-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b54f0d8f964a52043d427e3',
#        'name': "Mike's Bagels",
#        'location': {'address': '4003 Broadway',
#         'crossStreet': 'at W 168th St',
#         'lat': 40.84130375074571,
#         'lng': -73.93969147132887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84130375074571,
#           'lng': -73.93969147132887}],
#         'distance': 227,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4003 Broadway (at W 168th St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b54f0d8f964a52043d427e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583235438ee5605dc5046a14',
#        'name': 'Super Foodtown',
#        'location': {'address': '600 W. 160th St',
#         'crossStreet': 'Broadway',
#         'lat': 40.83599348703258,
#         'lng': -73.94397293915378,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83599348703258,
#           'lng': -73.94397293915378}],
#         'distance': 469,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['600 W. 160th St (Broadway)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '451447997'}},
#       'referralId': 'e-0-583235438ee5605dc5046a14-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519baeaf498e8296a5d7134a',
#        'name': 'Sweet Life Pastry',
#        'location': {'address': '3887 Broadway',
#         'crossStreet': 'between 162nd St and 163rd St',
#         'lat': 40.837455726622416,
#         'lng': -73.9424274449852,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.837455726622416,
#           'lng': -73.9424274449852}],
#         'distance': 269,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3887 Broadway (between 162nd St and 163rd St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '287220',
#         'url': 'https://www.seamless.com/menu/sweet-life-pastry-3887-broadway-ave-new-york/287220?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=287220',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519baeaf498e8296a5d7134a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbac3eecf2fc9b6a8f2a102',
#        'name': 'Labella Nail And Spa',
#        'location': {'address': '4033 Broadway',
#         'lat': 40.84220876634407,
#         'lng': -73.93918191041098,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84220876634407,
#           'lng': -73.93918191041098}],
#         'distance': 333,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4033 Broadway',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbac3eecf2fc9b6a8f2a102-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfe75a2feec6dcb0d1b5836',
#        'name': 'Antika Restaurant & Pizzeria',
#        'location': {'address': '3924 Broadway',
#         'lat': 40.838778,
#         'lng': -73.94121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.838778,
#           'lng': -73.94121}],
#         'distance': 110,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3924 Broadway',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '87760603'}},
#       'referralId': 'e-0-4cfe75a2feec6dcb0d1b5836-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba26242f964a5207cf337e3',
#        'name': 'GoGo-Gi',
#        'location': {'address': '3908 Broadway',
#         'crossStreet': 'W. 164th',
#         'lat': 40.838097508511474,
#         'lng': -73.94194091981308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.838097508511474,
#           'lng': -73.94194091981308}],
#         'distance': 189,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3908 Broadway (W. 164th)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba26242f964a5207cf337e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bde1145e75c0f474bccc603',
#        'name': 'Fort Washington Park',
#        'location': {'address': 'Hudson River Greenway',
#         'crossStreet': 'W. 155 St. to W. 179 St.',
#         'lat': 40.83809978015759,
#         'lng': -73.948974609375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83809978015759,
#           'lng': -73.948974609375}],
#         'distance': 660,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Hudson River Greenway (W. 155 St. to W. 179 St.)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bde1145e75c0f474bccc603-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9374b97b5ea1434f57c9b8',
#        'name': "Shana's Nail & Spa",
#        'location': {'address': '607 W 168th St',
#         'crossStreet': 'at Broadway',
#         'lat': 40.841279658392814,
#         'lng': -73.93973716918981,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.841279658392814,
#           'lng': -73.93973716918981}],
#         'distance': 222,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['607 W 168th St (at Broadway)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#          'name': 'Nail Salon',
#          'pluralName': 'Nail Salons',
#          'shortName': 'Nail Salon',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9374b97b5ea1434f57c9b8-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5092a9e2e4b0487f2a8da22d',
#        'name': 'Koronet Pizza',
#        'location': {'address': '4087 Broadway',
#         'crossStreet': '172 St',
#         'lat': 40.84423195082035,
#         'lng': -73.93897929578193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84423195082035,
#           'lng': -73.93897929578193}],
#         'distance': 539,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4087 Broadway (172 St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '284834',
#         'url': 'https://www.seamless.com/menu/koronet-pizza-4087-broadway-ave-new-york/284834?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=284834',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5092a9e2e4b0487f2a8da22d-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfb741852b145696e36c628',
#        'name': 'Presbyterian Deli 2',
#        'location': {'address': '2119 Amsterdam Ave',
#         'lat': 40.837875943201134,
#         'lng': -73.93853376958313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.837875943201134,
#           'lng': -73.93853376958313}],
#         'distance': 322,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['2119 Amsterdam Ave',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '314311',
#         'url': 'https://www.seamless.com/menu/164-presbyterian-deli-1081-st-nicholas-ave-new-york/314311?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=314311',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfb741852b145696e36c628-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514f59b9e4b08735dc007db7',
#        'name': 'Marjorie Eliot Parlor Entertainment Jazz',
#        'location': {'address': '555 Edgecombe Ave',
#         'lat': 40.834003030260874,
#         'lng': -73.93904254453047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.834003030260874,
#           'lng': -73.93904254453047}],
#         'distance': 671,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['555 Edgecombe Ave',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7931735',
#          'name': 'Jazz Club',
#          'pluralName': 'Jazz Clubs',
#          'shortName': 'Jazz Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514f59b9e4b08735dc007db7-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1a328df964a52016e823e3',
#        'name': 'La Barca Restaurant',
#        'location': {'address': '3892 Broadway',
#         'crossStreet': 'btwn 163rd & 162nd st',
#         'lat': 40.837514875359574,
#         'lng': -73.94231208440945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.837514875359574,
#           'lng': -73.94231208440945}],
#         'distance': 259,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3892 Broadway (btwn 163rd & 162nd st)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1032117',
#         'url': 'https://www.seamless.com/menu/la-barca-restaurant-3892-broadway-new-york/1032117?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1032117',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73015198'}},
#       'referralId': 'e-0-4b1a328df964a52016e823e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf6de355317a59304fbfc7e',
#        'name': 'Riverside Drive Dog Run',
#        'location': {'address': 'Riverside drive',
#         'crossStreet': 'at W165th',
#         'lat': 40.8410170667918,
#         'lng': -73.94518086892687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8410170667918,
#           'lng': -73.94518086892687}],
#         'distance': 344,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Riverside drive (at W165th)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf6de355317a59304fbfc7e-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523c757f11d2bbf1b13f0aee',
#        'name': 'Tung Thong Thai Restaurant',
#        'location': {'address': '561 W 169th St',
#         'crossStreet': 'bet St. Nicholas Ave And Audobon Ave',
#         'lat': 40.84145073169169,
#         'lng': -73.938856315647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84145073169169,
#           'lng': -73.938856315647}],
#         'distance': 288,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['561 W 169th St (bet St. Nicholas Ave And Audobon Ave)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '283923',
#         'url': 'https://www.seamless.com/menu/tung-thong-thai-restaurant-561-w-169th-st-new-york/283923?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=283923',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523c757f11d2bbf1b13f0aee-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a2eb22df964a52035981fe3',
#        'name': 'El Malecon',
#        'location': {'address': '4141 Broadway',
#         'crossStreet': 'at W 175th St.',
#         'lat': 40.84627438291493,
#         'lng': -73.93853526425761,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84627438291493,
#           'lng': -73.93853526425761}],
#         'distance': 765,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4141 Broadway (at W 175th St.)',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a2eb22df964a52035981fe3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c69e8d61a6620a138f0648c',
#        'name': 'La Reina del Chicharron',
#        'location': {'address': '1249 Saint Nicholas Ave',
#         'crossStreet': '172nd and 173rd',
#         'lat': 40.84379037716057,
#         'lng': -73.93780613668747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84379037716057,
#           'lng': -73.93780613668747}],
#         'distance': 543,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1249 Saint Nicholas Ave (172nd and 173rd)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c69e8d61a6620a138f0648c-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d348824c75a6ea8276120ae',
#        'name': 'Jumel Terrace Historic District',
#        'location': {'lat': 40.83554567606681,
#         'lng': -73.93787497859708,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83554567606681,
#           'lng': -73.93787497859708}],
#         'distance': 556,
#         'cc': 'US',
#         'state': 'New York',
#         'country': 'United States',
#         'formattedAddress': ['New York', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d348824c75a6ea8276120ae-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5100025b19a9b90e8753b186',
#        'name': 'Taszo Espresso Bar',
#        'location': {'address': '5 Edward M Morgan Pl',
#         'crossStreet': 'b/t 157th and 158th Streets',
#         'lat': 40.83446523736186,
#         'lng': -73.94527403283722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83446523736186,
#           'lng': -73.94527403283722}],
#         'distance': 671,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['5 Edward M Morgan Pl (b/t 157th and 158th Streets)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '345857',
#         'url': 'https://www.seamless.com/menu/taszo-espresso-bar-5-edward-m-morgan-pl-new-york/345857?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=345857',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55134296'}},
#       'referralId': 'e-0-5100025b19a9b90e8753b186-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eea603cbe7b7263daa77dbe',
#        'name': 'Bubbles R Us Laundromat',
#        'location': {'address': '1026 Saint Nicholas Ave',
#         'crossStreet': 'W 162nd St',
#         'lat': 40.83536563504299,
#         'lng': -73.94009521749362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83536563504299,
#           'lng': -73.94009521749362}],
#         'distance': 501,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1026 Saint Nicholas Ave (W 162nd St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fc941735',
#          'name': 'Laundry Service',
#          'pluralName': 'Laundry Services',
#          'shortName': 'Laundry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eea603cbe7b7263daa77dbe-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b69934ef964a520fea72be3',
#        'name': 'Morris Jumel Mansion',
#        'location': {'address': '65 Jumel Ter',
#         'crossStreet': 'btwn 160th &162nd St',
#         'lat': 40.83442673031622,
#         'lng': -73.9385998249054,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83442673031622,
#           'lng': -73.9385998249054}],
#         'distance': 639,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['65 Jumel Ter (btwn 160th &162nd St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b69934ef964a520fea72be3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be42c292457a59316d4a915',
#        'name': 'Jay Hood Wright Park',
#        'location': {'address': '351 Fort Washington Ave',
#         'crossStreet': 'at W 173rd St.',
#         'lat': 40.84732991887064,
#         'lng': -73.93969238409115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84732991887064,
#           'lng': -73.93969238409115}],
#         'distance': 856,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['351 Fort Washington Ave (at W 173rd St.)',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be42c292457a59316d4a915-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b96f9e63731ee002caf7833',
#        'name': 'Boxers Washington Heights',
#        'location': {'address': '3820 Broadway',
#         'crossStreet': '159th Street',
#         'lat': 40.83532153848655,
#         'lng': -73.9439586626559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83532153848655,
#           'lng': -73.9439586626559}],
#         'distance': 537,
#         'postalCode': '10032',
#         'cc': 'US',
#         'neighborhood': 'Washington Heights',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3820 Broadway (159th Street)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1436153',
#         'url': 'https://www.seamless.com/menu/boxersnyc-washington-heights-3820-broadway-new-york/1436153?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1436153',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b96f9e63731ee002caf7833-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe9524ce4b0d971aa120f82',
#        'name': 'Galaxy Gourmet Deli',
#        'location': {'address': '3778 Broadway',
#         'crossStreet': '157St',
#         'lat': 40.83386754690855,
#         'lng': -73.94483908573643,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83386754690855,
#           'lng': -73.94483908573643}],
#         'distance': 714,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3778 Broadway (157St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '317563',
#         'url': 'https://www.seamless.com/menu/galaxy-gourmet-3778-broadway-new-york/317563?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=317563',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe9524ce4b0d971aa120f82-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbb75fabac93704fd46f27c',
#        'name': 'Empanadas Monumental',
#        'location': {'address': '4093 Broadway',
#         'crossStreet': 'btwn 172nd & 173rd St.',
#         'lat': 40.84448866442702,
#         'lng': -73.93888144527996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84448866442702,
#           'lng': -73.93888144527996}],
#         'distance': 569,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4093 Broadway (btwn 172nd & 173rd St.)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '52939a8c3cf9994f4e043a35',
#          'name': 'Empanada Restaurant',
#          'pluralName': 'Empanada Restaurants',
#          'shortName': 'Empanada',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '299632',
#         'url': 'https://www.seamless.com/menu/empanadas-monumental-4093-broadway-new-york/299632?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299632',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '81751713'}},
#       'referralId': 'e-0-4cbb75fabac93704fd46f27c-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3e62a5f964a5204e9c25e3',
#        'name': 'Chase Bank',
#        'location': {'address': '3940 Broadway',
#         'lat': 40.83919759698646,
#         'lng': -73.9406543970108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83919759698646,
#           'lng': -73.9406543970108}],
#         'distance': 91,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3940 Broadway',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3e62a5f964a5204e9c25e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '460d50e2f964a52008451fe3',
#        'name': 'United Palace',
#        'location': {'address': '4140 Broadway',
#         'crossStreet': 'at W 175th St',
# ...
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3750 Broadway',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c64998bdddfa593081492ff-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a937bb498e8b18ac5e28e0',
#        'name': "Dunkin'",
#        'location': {'address': '1995 Amsterdam Ave',
#         'crossStreet': '159th St',
#         'lat': 40.833955022980795,
#         'lng': -73.94100275337297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.833955022980795,
#           'lng': -73.94100275337297}],
#         'distance': 646,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1995 Amsterdam Ave (159th St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1169194',
#         'url': 'https://www.seamless.com/menu/dunkin-1995-amsterdam-ave-new-york/1169194?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1169194',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a937bb498e8b18ac5e28e0-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bb1b080cad1b60039763481',
#        'name': 'Hilltop Park Alehouse',
#        'location': {'crossStreet': '159th Street',
#         'lat': 40.835336554142934,
#         'lng': -73.94401638608784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.835336554142934,
#           'lng': -73.94401638608784}],
#         'distance': 537,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['159th Street',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1273497',
#         'url': 'https://www.seamless.com/menu/hilltop-park-alehouse-3821-broadway-new-york/1273497?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1273497',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bb1b080cad1b60039763481-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49f23c80f964a520116a1fe3',
#        'name': 'El Floridita Restaurant',
#        'location': {'address': '4162 Broadway',
#         'crossStreet': '177th St',
#         'lat': 40.84730277233024,
#         'lng': -73.93815796384422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84730277233024,
#           'lng': -73.93815796384422}],
#         'distance': 884,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4162 Broadway (177th St)',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'shortName': 'Cuban',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '518884',
#         'url': 'https://www.seamless.com/menu/floridita-4162-broadway-new-york/518884?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=518884',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49f23c80f964a520116a1fe3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '542db567498e62837f861bae',
#        'name': '7-Eleven',
#        'location': {'address': '600 W 178th St',
#         'crossStreet': 'St Nicolas Avenue',
#         'lat': 40.8473168696316,
#         'lng': -73.9354385656414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8473168696316,
#           'lng': -73.9354385656414}],
#         'distance': 982,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['600 W 178th St (St Nicolas Avenue)',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-542db567498e62837f861bae-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb8bd66a33bb1f7458683fd',
#        'name': 'Riverside Deli',
#        'location': {'address': '3779 Edward Morgan Place',
#         'crossStreet': 'W 157th St',
#         'lat': 40.834174,
#         'lng': -73.945578,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.834174,
#           'lng': -73.945578}],
#         'distance': 712,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3779 Edward Morgan Place (W 157th St)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb8bd66a33bb1f7458683fd-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d29737498edd288dae4f0f',
#        'name': 'Caffé Bene',
#        'location': {'address': '9 Edward M Morgan Pl',
#         'crossStreet': 'West 157th street',
#         'lat': 40.834501909616236,
#         'lng': -73.94534933399785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.834501909616236,
#           'lng': -73.94534933399785}],
#         'distance': 670,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['9 Edward M Morgan Pl (West 157th street)',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d29737498edd288dae4f0f-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589e949bc0c89b31d22f7e3d',
#        'name': "Domino's Pizza",
#        'location': {'address': '1988 Amsterdam Ave',
#         'lat': 40.83394402938033,
#         'lng': -73.94153629447749,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.83394402938033,
#           'lng': -73.94153629447749}],
#         'distance': 647,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1988 Amsterdam Ave',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589e949bc0c89b31d22f7e3d-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fe8bf6498ec4be7954093c',
#        'name': 'Tu Cachapa',
#        'location': {'address': '4195 Broadway',
#         'crossStreet': '178',
#         'lat': 40.848210455280594,
#         'lng': -73.93774273133336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.848210455280594,
#           'lng': -73.93774273133336}],
#         'distance': 991,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4195 Broadway (178)',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d152941735',
#          'name': 'Arepa Restaurant',
#          'pluralName': 'Arepa Restaurants',
#          'shortName': 'Arepas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/arepas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '283278',
#         'url': 'https://www.seamless.com/menu/tu-cachapa-4195-broadway-ave-new-york/283278?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=283278',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fe8bf6498ec4be7954093c-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba78292f964a520339939e3',
#        'name': 'C-Town Supermarkets',
#        'location': {'address': '1314 Saint Nicholas Ave',
#         'lat': 40.84581,
#         'lng': -73.935873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.84581,
#           'lng': -73.935873}],
#         'distance': 821,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1314 Saint Nicholas Ave',
#          'New York, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba78292f964a520339939e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c768e47d8948cfac3b56ada',
#        'name': "Dunkin'",
#        'location': {'address': '3833 Broadway',
#         'lat': 40.835774209545335,
#         'lng': -73.94402020496614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.835774209545335,
#           'lng': -73.94402020496614}],
#         'distance': 493,
#         'postalCode': '10032',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['3833 Broadway',
#          'New York, NY 10032',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1171352',
#         'url': 'https://www.seamless.com/menu/dunkin-3833-broadway-new-york/1171352?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1171352',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c768e47d8948cfac3b56ada-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5767ddab498e7d23f5deaec3',
#        'name': 'IHOP',
#        'location': {'address': '4168 Broadway',
#         'lat': 40.847516362537625,
#         'lng': -73.93792559201754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.847516362537625,
#           'lng': -73.93792559201754}],
#         'distance': 913,
#         'postalCode': '10033',
#         'cc': 'US',
#         'city': 'Manhattan',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4168 Broadway',
#          'Manhattan, NY 10033',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5767ddab498e7d23f5deaec3-99'}]}]}}

# %%
venues = venues_json['response']['groups'][0]['items']
venues_df = json_normalize(venues)

# %%
venues_df.columns
# Out:
# Index(['reasons.count', 'reasons.items', 'referralId', 'venue.categories',
#        'venue.delivery.id', 'venue.delivery.provider.icon.name',
#        'venue.delivery.provider.icon.prefix',
#        'venue.delivery.provider.icon.sizes', 'venue.delivery.provider.name',
#        'venue.delivery.url', 'venue.id', 'venue.location.address',
#        'venue.location.cc', 'venue.location.city', 'venue.location.country',
#        'venue.location.crossStreet', 'venue.location.distance',
#        'venue.location.formattedAddress', 'venue.location.labeledLatLngs',
#        'venue.location.lat', 'venue.location.lng',
#        'venue.location.neighborhood', 'venue.location.postalCode',
#        'venue.location.state', 'venue.name', 'venue.photos.count',
#        'venue.photos.groups', 'venue.venuePage.id'],
#       dtype='object')

# %%
# lets define our columns of interest i.e. venue.categories , venue.id , venue.name , venue.location.lat','venue.location.lng'.

columns_of_interest = ['venue.name','venue.categories','venue.id','venue.location.lat','venue.location.lng']

venues_filtered_df = venues_df.loc[:,columns_of_interest]
venues_filtered_df.head()
# Out:
#                              venue.name  \
# 0                       Highbridge Park
# 1                   Carrot Top Pastries
# 2                            Las Palmas
# 3                 Columbia Wine Company
# 4  Word Up: Community Bookshop/Libreria
#
#                                     venue.categories  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...
# 3  [{'id': '4bf58dd8d48988d119951735', 'name': 'W...
# 4  [{'id': '4bf58dd8d48988d114951735', 'name': 'B...
#
#                    venue.id  venue.location.lat  venue.location.lng
# 0  4ac93103f964a52013bf20e3           40.840768          -73.942927
# 1  4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2  4b68d051f964a520518e2be3           40.837575          -73.942351
# 3  506cc066e4b019e8dad3a401           40.842076          -73.938801
# 4  4dfe3f6bd4c01dccaebd615a           40.837839          -73.938292

# %%
# We need some data cleaning on venue.categories column.

venues_filtered_df.loc[0,'venue.categories']
# Out:
# [{'id': '4bf58dd8d48988d163941735',
#   'name': 'Park',
#   'pluralName': 'Parks',
#   'shortName': 'Park',
#   'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#    'suffix': '.png'},
#   'primary': True}]

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
venues_filtered_df['venue.categories'] = venues_filtered_df.apply(get_category_type,axis = 1)
venues_filtered_df
# Out:
#                                         venue.name           venue.categories  \
# 0                                  Highbridge Park                       Park
# 1                              Carrot Top Pastries                     Bakery
# 2                                       Las Palmas         Mexican Restaurant
# 3                            Columbia Wine Company                  Wine Shop
# 4             Word Up: Community Bookshop/Libreria                  Bookstore
# 5   New Balance Track & Field Center at The Armory                      Track
# 6       Fort Washington Greenmarket Farmers Market             Farmers Market
# 7                                       Tasty Deli             Sandwich Place
# 8                                          Rain II            Thai Restaurant
# 9                                    Mike's Bagels                 Bagel Shop
# 10                                  Super Foodtown                Supermarket
# 11                               Sweet Life Pastry                     Bakery
# 12                            Labella Nail And Spa                        Spa
# 13                    Antika Restaurant & Pizzeria         Italian Restaurant
# 14                                         GoGo-Gi          Korean Restaurant
# 15                            Fort Washington Park                       Park
# 16                              Shana's Nail & Spa                 Nail Salon
# 17                                   Koronet Pizza                Pizza Place
# 18                             Presbyterian Deli 2              Deli / Bodega
# 19        Marjorie Eliot Parlor Entertainment Jazz                  Jazz Club
# 20                             La Barca Restaurant  Latin American Restaurant
# 21                         Riverside Drive Dog Run                    Dog Run
# 22                      Tung Thong Thai Restaurant            Thai Restaurant
# 23                                      El Malecon  Latin American Restaurant
# 24                         La Reina del Chicharron  Latin American Restaurant
# 25                 Jumel Terrace Historic District                      Plaza
# 26                              Taszo Espresso Bar                Coffee Shop
# 27                         Bubbles R Us Laundromat            Laundry Service
# 28                            Morris Jumel Mansion             History Museum
# 29                            Jay Hood Wright Park                       Park
# ..                                             ...                        ...
# 70                         J. Hood Wright Dog Park                    Dog Run
# 71                            Blue Corn Restaurant         Mexican Restaurant
# 72                         Restaurante La Libertad  Latin American Restaurant
# 73                           Manhattan Beach - GWB                      Beach
# 74                                       Taco Bell       Fast Food Restaurant
# 75                               Subway Sandwiches             Sandwich Place
# 76                            Little Caesars Pizza                Pizza Place
# 77                                         Subways             Sandwich Place
# 78                                             GNC            Supplement Shop
# 79                                          Subway             Sandwich Place
# 80                            Little Caesars Pizza                Pizza Place
# 81                             El Conde Steakhouse         Spanish Restaurant
# 82                                    Pick and Eat                       Café
# 83                 El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                                Flaco's Pizzeria                Pizza Place
# 85                                         Dunkin'                 Donut Shop
# 86                                     Chimi Luisa                 Food Truck
# 87                       Floridita Broadway Bakery                     Bakery
# 88                               Subway Sandwiches             Sandwich Place
# 89                                         Dunkin'                 Donut Shop
# 90                           Hilltop Park Alehouse                        Bar
# 91                         El Floridita Restaurant           Cuban Restaurant
# 92                                        7-Eleven          Convenience Store
# 93                                  Riverside Deli              Deli / Bodega
# 94                                      Caffé Bene                       Café
# 95                                  Domino's Pizza                Pizza Place
# 96                                      Tu Cachapa           Arepa Restaurant
# 97                             C-Town Supermarkets              Grocery Store
# 98                                         Dunkin'                 Donut Shop
# 99                                            IHOP             Breakfast Spot
#
#                     venue.id  venue.location.lat  venue.location.lng
# 0   4ac93103f964a52013bf20e3           40.840768          -73.942927
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 3   506cc066e4b019e8dad3a401           40.842076          -73.938801
# 4   4dfe3f6bd4c01dccaebd615a           40.837839          -73.938292
# 5   4b5b0144f964a5205fde28e3           40.842379          -73.941875
# 6   4e416857d164f2d277c2922a           40.842613          -73.942065
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 10  583235438ee5605dc5046a14           40.835993          -73.943973
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 12  4bbac3eecf2fc9b6a8f2a102           40.842209          -73.939182
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 15  4bde1145e75c0f474bccc603           40.838100          -73.948975
# 16  4d9374b97b5ea1434f57c9b8           40.841280          -73.939737
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 18  4dfb741852b145696e36c628           40.837876          -73.938534
# 19  514f59b9e4b08735dc007db7           40.834003          -73.939043
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 21  4bf6de355317a59304fbfc7e           40.841017          -73.945181
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 25  4d348824c75a6ea8276120ae           40.835546          -73.937875
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 27  4eea603cbe7b7263daa77dbe           40.835366          -73.940095
# 28  4b69934ef964a520fea72be3           40.834427          -73.938600
# 29  4be42c292457a59316d4a915           40.847330          -73.939692
# ..                       ...                 ...                 ...
# 70  4b16d62bf964a52027be23e3           40.846596          -73.942219
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 73  4c9e5a3fca44236a810b2a99           40.845176          -73.944159
# 74  576ddcad498e43657f66b02e           40.847168          -73.935350
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 78  580779f838faaedf9d863093           40.834716          -73.944793
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 81  4b04b9a2f964a5205a5622e3           40.846096          -73.938442
# 82  4d2d39b469f42d439d16ad8a           40.847558          -73.938212
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 86  4c26f2c2a852c928119be76c           40.845551          -73.934963
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 90  5bb1b080cad1b60039763481           40.835337          -73.944016
# 91  49f23c80f964a520116a1fe3           40.847303          -73.938158
# 92  542db567498e62837f861bae           40.847317          -73.935439
# 93  4cb8bd66a33bb1f7458683fd           40.834174          -73.945578
# 94  53d29737498edd288dae4f0f           40.834502          -73.945349
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 96  51fe8bf6498ec4be7954093c           40.848210          -73.937743
# 97  4ba78292f964a520339939e3           40.845810          -73.935873
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020
# 99  5767ddab498e7d23f5deaec3           40.847516          -73.937926
#
# [100 rows x 5 columns]

# %%
venues_filtered_df['venue.categories'].value_counts()
# Out:
# Latin American Restaurant    8
# Pizza Place                  6
# Sandwich Place               5
# Mexican Restaurant           5
# Grocery Store                4
# Café                         3
# Bakery                       3
# Bar                          3
# Deli / Bodega                3
# Spanish Restaurant           3
# Park                         3
# Donut Shop                   3
# Empanada Restaurant          2
# Coffee Shop                  2
# Supermarket                  2
# Dog Run                      2
# History Museum               2
# Gym / Fitness Center         2
# Thai Restaurant              2
# New American Restaurant      2
# Mobile Phone Shop            2
# Italian Restaurant           2
# Bookstore                    2
# Plaza                        1
# Wine Bar                     1
# Lounge                       1
# Bagel Shop                   1
# Jazz Club                    1
# Diner                        1
# Nail Salon                   1
# Korean Restaurant            1
# Food Truck                   1
# Wine Shop                    1
# Track                        1
# Beach                        1
# Spa                          1
# Tapas Restaurant             1
# Farmers Market               1
# Arepa Restaurant             1
# Art Museum                   1
# Cuban Restaurant             1
# BBQ Joint                    1
# Historic Site                1
# Laundry Service              1
# Supplement Shop              1
# Arts & Crafts Store          1
# Convenience Store            1
# Fast Food Restaurant         1
# Music Venue                  1
# Bank                         1
# Chinese Restaurant           1
# Breakfast Spot               1
# Name: venue.categories, dtype: int64

# %%
# Lets create a list of all food places from the above categories.

restaurant_list = ['Pizza Place','Sandwich Place','Mexican Restaurant','Chinese Restaurant','Bakery','Thai Restaurant','Latin American Restaurant','Italian Restaurant','Korean Restaurant','Donut Shop','Coffee Shop','Bubble Tea Shop','Bagel Shop','New American Restaurant','Diner','BBQ Joint']

venues_filtered_df = venues_filtered_df[venues_filtered_df['venue.categories'].isin(restaurant_list)]
venues_filtered_df
# Out:
#                           venue.name           venue.categories  \
# 1                Carrot Top Pastries                     Bakery
# 2                         Las Palmas         Mexican Restaurant
# 7                         Tasty Deli             Sandwich Place
# 8                            Rain II            Thai Restaurant
# 9                      Mike's Bagels                 Bagel Shop
# 11                 Sweet Life Pastry                     Bakery
# 13      Antika Restaurant & Pizzeria         Italian Restaurant
# 14                           GoGo-Gi          Korean Restaurant
# 17                     Koronet Pizza                Pizza Place
# 20               La Barca Restaurant  Latin American Restaurant
# 22        Tung Thong Thai Restaurant            Thai Restaurant
# 23                        El Malecon  Latin American Restaurant
# 24           La Reina del Chicharron  Latin American Restaurant
# 26                Taszo Espresso Bar                Coffee Shop
# 35                        Wahi Diner                      Diner
# 36       Tropical Spanish Restaurant  Latin American Restaurant
# 39                      El Pitallito         Mexican Restaurant
# 46                        Dallas BBQ                  BBQ Joint
# 48                   Famous Famiglia                Pizza Place
# 49                        AquaMarina         Italian Restaurant
# 50            Chipotle Mexican Grill         Mexican Restaurant
# 53                         Starbucks                Coffee Shop
# 59               El Capri Restaurant  Latin American Restaurant
# 60  Silver Palace Chinese Restaurant         Chinese Restaurant
# 62                   Tu Sabor Latino  Latin American Restaurant
# 63              La Fiesta Restaurant         Mexican Restaurant
# 67                         Terravita    New American Restaurant
# 69             Windows On The Hudson    New American Restaurant
# 71              Blue Corn Restaurant         Mexican Restaurant
# 72           Restaurante La Libertad  Latin American Restaurant
# 75                 Subway Sandwiches             Sandwich Place
# 76              Little Caesars Pizza                Pizza Place
# 77                           Subways             Sandwich Place
# 79                            Subway             Sandwich Place
# 80              Little Caesars Pizza                Pizza Place
# 83   El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                  Flaco's Pizzeria                Pizza Place
# 85                           Dunkin'                 Donut Shop
# 87         Floridita Broadway Bakery                     Bakery
# 88                 Subway Sandwiches             Sandwich Place
# 89                           Dunkin'                 Donut Shop
# 95                    Domino's Pizza                Pizza Place
# 98                           Dunkin'                 Donut Shop
#
#                     venue.id  venue.location.lat  venue.location.lng
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 46  4b0f0881f964a5205f5e23e3           40.839860          -73.940509
# 48  4bcfc9ceb221c9b6e3c9d2d0           40.841334          -73.939577
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 53  4b25a38bf964a520dc7424e3           40.841188          -73.939843
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020

# %%
## Now, we have Dataframe of all nearby restaurants , using FourSquare API we can pull 'like count' for each restaurant.

## lets try to pull like count for 'Carrot Top Pastries' using venue id and later we will do for all restaurants.

venueid = '4b2ce776f964a5208fca24e3' ##venue id of 'Carrot Top Pastries'.
url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(venueid, CLIENT_ID, CLIENT_SECRET, VERSION)

venue_json = requests.get(url).json()

like_count = venue_json['response']['likes']['count']
like_count
# Out:
# 62

# %%
## Let define a function to pull out likes for each restaurant and try to append it to our dataframe.

def like_count(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    venue_json = requests.get(url).json()
    likes = venue_json['response']['likes']['count']
    return likes

venues_filtered_df['Like Count'] = venues_filtered_df['venue.id'].apply(like_count)
venues_filtered_df
# Out:
# C:\Users\akshay.nagar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                           venue.name           venue.categories  \
# 1                Carrot Top Pastries                     Bakery
# 2                         Las Palmas         Mexican Restaurant
# 7                         Tasty Deli             Sandwich Place
# 8                            Rain II            Thai Restaurant
# 9                      Mike's Bagels                 Bagel Shop
# 11                 Sweet Life Pastry                     Bakery
# 13      Antika Restaurant & Pizzeria         Italian Restaurant
# 14                           GoGo-Gi          Korean Restaurant
# 17                     Koronet Pizza                Pizza Place
# 20               La Barca Restaurant  Latin American Restaurant
# 22        Tung Thong Thai Restaurant            Thai Restaurant
# 23                        El Malecon  Latin American Restaurant
# 24           La Reina del Chicharron  Latin American Restaurant
# 26                Taszo Espresso Bar                Coffee Shop
# 35                        Wahi Diner                      Diner
# 36       Tropical Spanish Restaurant  Latin American Restaurant
# 39                      El Pitallito         Mexican Restaurant
# 46                        Dallas BBQ                  BBQ Joint
# 48                   Famous Famiglia                Pizza Place
# 49                        AquaMarina         Italian Restaurant
# 50            Chipotle Mexican Grill         Mexican Restaurant
# 53                         Starbucks                Coffee Shop
# 59               El Capri Restaurant  Latin American Restaurant
# 60  Silver Palace Chinese Restaurant         Chinese Restaurant
# 62                   Tu Sabor Latino  Latin American Restaurant
# 63              La Fiesta Restaurant         Mexican Restaurant
# 67                         Terravita    New American Restaurant
# 69             Windows On The Hudson    New American Restaurant
# 71              Blue Corn Restaurant         Mexican Restaurant
# 72           Restaurante La Libertad  Latin American Restaurant
# 75                 Subway Sandwiches             Sandwich Place
# 76              Little Caesars Pizza                Pizza Place
# 77                           Subways             Sandwich Place
# 79                            Subway             Sandwich Place
# 80              Little Caesars Pizza                Pizza Place
# 83   El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                  Flaco's Pizzeria                Pizza Place
# 85                           Dunkin'                 Donut Shop
# 87         Floridita Broadway Bakery                     Bakery
# 88                 Subway Sandwiches             Sandwich Place
# 89                           Dunkin'                 Donut Shop
# 95                    Domino's Pizza                Pizza Place
# 98                           Dunkin'                 Donut Shop
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 46  4b0f0881f964a5205f5e23e3           40.839860          -73.940509
# 48  4bcfc9ceb221c9b6e3c9d2d0           40.841334          -73.939577
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 53  4b25a38bf964a520dc7424e3           40.841188          -73.939843
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020
#
#     Like Count
# 1           62
# 2           47
# 7           47
# 8           18
# 9           49
# 11          15
# 13          63
# 14          33
# 17          46
# 20           7
# 22          34
# 23         230
# 24           9
# 26         198
# 35          72
# 36          13
# 39           6
# 46         131
# 48          12
# 49          14
# 50          92
# 53         141
# 59           5
# 60           5
# 62           4
# 63          12
# 67           6
# 69           1
# 71           6
# 72          19
# 75           3
# 76          10
# 77           0
# 79           1
# 80           4
# 83           6
# 84           7
# 85           9
# 87           8
# 88           2
# 89           5
# 95           0
# 98          14

# %%
## Let's make a copy of our dataframe in case if anything goes wrong.

newyork_venues_df = venues_filtered_df

# %%
## We have total likes for each nearby restaurant. Let categorize them based on their likes.

## To do so , first we need statistics about likes ( minimum , maximum , average and so on).
## Then we'll define categories and will label each restaurant.

newyork_venues_df['Like Count'].describe()
# Out:
# count     43.000000
# mean      34.093023
# std       52.157186
# min        0.000000
# 25%        5.500000
# 50%       12.000000
# 75%       46.500000
# max      230.000000
# Name: Like Count, dtype: float64

# %%
#Now let's define categories for Like Range:
# Like Count <= 5 i.e. Very Poor
# Like Count > 5 and <=11 i.e. Poor
# Like Count > 11 and <=46 i.e. Average
# Like Count > 46 i.e. Good

def define_rating(likes):
    if(likes <= 5):
        return 'Very Poor'
    elif(likes > 5 and likes <= 11):
        return 'Poor'
    elif(likes > 11 and likes <= 46):
        return 'Average'
    elif(likes > 46):
        return 'Good'
    
newyork_venues_df['Rated Category'] = newyork_venues_df['Like Count'].apply(define_rating)
newyork_venues_df
# Out:
# C:\Users\akshay.nagar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                           venue.name           venue.categories  \
# 1                Carrot Top Pastries                     Bakery
# 2                         Las Palmas         Mexican Restaurant
# 7                         Tasty Deli             Sandwich Place
# 8                            Rain II            Thai Restaurant
# 9                      Mike's Bagels                 Bagel Shop
# 11                 Sweet Life Pastry                     Bakery
# 13      Antika Restaurant & Pizzeria         Italian Restaurant
# 14                           GoGo-Gi          Korean Restaurant
# 17                     Koronet Pizza                Pizza Place
# 20               La Barca Restaurant  Latin American Restaurant
# 22        Tung Thong Thai Restaurant            Thai Restaurant
# 23                        El Malecon  Latin American Restaurant
# 24           La Reina del Chicharron  Latin American Restaurant
# 26                Taszo Espresso Bar                Coffee Shop
# 35                        Wahi Diner                      Diner
# 36       Tropical Spanish Restaurant  Latin American Restaurant
# 39                      El Pitallito         Mexican Restaurant
# 46                        Dallas BBQ                  BBQ Joint
# 48                   Famous Famiglia                Pizza Place
# 49                        AquaMarina         Italian Restaurant
# 50            Chipotle Mexican Grill         Mexican Restaurant
# 53                         Starbucks                Coffee Shop
# 59               El Capri Restaurant  Latin American Restaurant
# 60  Silver Palace Chinese Restaurant         Chinese Restaurant
# 62                   Tu Sabor Latino  Latin American Restaurant
# 63              La Fiesta Restaurant         Mexican Restaurant
# 67                         Terravita    New American Restaurant
# 69             Windows On The Hudson    New American Restaurant
# 71              Blue Corn Restaurant         Mexican Restaurant
# 72           Restaurante La Libertad  Latin American Restaurant
# 75                 Subway Sandwiches             Sandwich Place
# 76              Little Caesars Pizza                Pizza Place
# 77                           Subways             Sandwich Place
# 79                            Subway             Sandwich Place
# 80              Little Caesars Pizza                Pizza Place
# 83   El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                  Flaco's Pizzeria                Pizza Place
# 85                           Dunkin'                 Donut Shop
# 87         Floridita Broadway Bakery                     Bakery
# 88                 Subway Sandwiches             Sandwich Place
# 89                           Dunkin'                 Donut Shop
# 95                    Domino's Pizza                Pizza Place
# 98                           Dunkin'                 Donut Shop
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 46  4b0f0881f964a5205f5e23e3           40.839860          -73.940509
# 48  4bcfc9ceb221c9b6e3c9d2d0           40.841334          -73.939577
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 53  4b25a38bf964a520dc7424e3           40.841188          -73.939843
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020
#
#     Like Count Rated Category
# 1           62           Good
# 2           47           Good
# 7           47           Good
# 8           18        Average
# 9           49           Good
# 11          15        Average
# 13          63           Good
# 14          33        Average
# 17          46        Average
# 20           7           Poor
# 22          34        Average
# 23         230           Good
# 24           9           Poor
# 26         198           Good
# 35          72           Good
# 36          13        Average
# 39           6           Poor
# 46         131           Good
# 48          12        Average
# 49          14        Average
# 50          92           Good
# 53         141           Good
# 59           5      Very Poor
# 60           5      Very Poor
# 62           4      Very Poor
# 63          12        Average
# 67           6           Poor
# 69           1      Very Poor
# 71           6           Poor
# 72          19        Average
# 75           3      Very Poor
# 76          10           Poor
# 77           0      Very Poor
# 79           1      Very Poor
# 80           4      Very Poor
# 83           6           Poor
# 84           7           Poor
# 85           9           Poor
# 87           8           Poor
# 88           2      Very Poor
# 89           5      Very Poor
# 95           0      Very Poor
# 98          14        Average

# %% [markdown]
# Let's Categorize all restaurants in 3 different groups i.e.
#  1. Fine Dine
#  2. Eatery
#  3. Bar

# %%
newyork_venues_df['venue.categories'].unique()
# Out:
# array(['Bakery', 'Mexican Restaurant', 'Sandwich Place',
#        'Thai Restaurant', 'Bagel Shop', 'Italian Restaurant',
#        'Korean Restaurant', 'Pizza Place', 'Latin American Restaurant',
#        'Coffee Shop', 'Diner', 'BBQ Joint', 'Chinese Restaurant',
#        'New American Restaurant', 'Donut Shop'], dtype=object)

# %%
Euro_Asian = ['Thai Restaurant','Italian Restaurant','Korean Restaurant','Chinese Restaurant']
American = ['Mexican Restaurant','Latin American Restaurant','Diner','New American Restaurant']
Eatery = ['Bakery','Sandwich Place','Bagel Shop','Pizza Place','Coffee Shop','Bubble Tea Shop','BBQ Joint','Donut Shop']

def restaurant_category(rest):
    if(rest in Euro_Asian):
        return 'Asian/European Food'
    elif(rest in American):
        return 'American Food'
    elif(rest in Eatery):
        return 'Eatery'
    
newyork_venues_df['Restaurant Category'] = newyork_venues_df['venue.categories'].apply(restaurant_category)
newyork_venues_df
# Out:
# C:\Users\akshay.nagar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                           venue.name           venue.categories  \
# 1                Carrot Top Pastries                     Bakery
# 2                         Las Palmas         Mexican Restaurant
# 7                         Tasty Deli             Sandwich Place
# 8                            Rain II            Thai Restaurant
# 9                      Mike's Bagels                 Bagel Shop
# 11                 Sweet Life Pastry                     Bakery
# 13      Antika Restaurant & Pizzeria         Italian Restaurant
# 14                           GoGo-Gi          Korean Restaurant
# 17                     Koronet Pizza                Pizza Place
# 20               La Barca Restaurant  Latin American Restaurant
# 22        Tung Thong Thai Restaurant            Thai Restaurant
# 23                        El Malecon  Latin American Restaurant
# 24           La Reina del Chicharron  Latin American Restaurant
# 26                Taszo Espresso Bar                Coffee Shop
# 35                        Wahi Diner                      Diner
# 36       Tropical Spanish Restaurant  Latin American Restaurant
# 39                      El Pitallito         Mexican Restaurant
# 46                        Dallas BBQ                  BBQ Joint
# 48                   Famous Famiglia                Pizza Place
# 49                        AquaMarina         Italian Restaurant
# 50            Chipotle Mexican Grill         Mexican Restaurant
# 53                         Starbucks                Coffee Shop
# 59               El Capri Restaurant  Latin American Restaurant
# 60  Silver Palace Chinese Restaurant         Chinese Restaurant
# 62                   Tu Sabor Latino  Latin American Restaurant
# 63              La Fiesta Restaurant         Mexican Restaurant
# 67                         Terravita    New American Restaurant
# 69             Windows On The Hudson    New American Restaurant
# 71              Blue Corn Restaurant         Mexican Restaurant
# 72           Restaurante La Libertad  Latin American Restaurant
# 75                 Subway Sandwiches             Sandwich Place
# 76              Little Caesars Pizza                Pizza Place
# 77                           Subways             Sandwich Place
# 79                            Subway             Sandwich Place
# 80              Little Caesars Pizza                Pizza Place
# 83   El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                  Flaco's Pizzeria                Pizza Place
# 85                           Dunkin'                 Donut Shop
# 87         Floridita Broadway Bakery                     Bakery
# 88                 Subway Sandwiches             Sandwich Place
# 89                           Dunkin'                 Donut Shop
# 95                    Domino's Pizza                Pizza Place
# 98                           Dunkin'                 Donut Shop
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 46  4b0f0881f964a5205f5e23e3           40.839860          -73.940509
# 48  4bcfc9ceb221c9b6e3c9d2d0           40.841334          -73.939577
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 53  4b25a38bf964a520dc7424e3           40.841188          -73.939843
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020
#
#     Like Count Rated Category  Restaurant Category
# 1           62           Good               Eatery
# 2           47           Good        American Food
# 7           47           Good               Eatery
# 8           18        Average  Asian/European Food
# 9           49           Good               Eatery
# 11          15        Average               Eatery
# 13          63           Good  Asian/European Food
# 14          33        Average  Asian/European Food
# 17          46        Average               Eatery
# 20           7           Poor        American Food
# 22          34        Average  Asian/European Food
# 23         230           Good        American Food
# 24           9           Poor        American Food
# 26         198           Good               Eatery
# 35          72           Good        American Food
# 36          13        Average        American Food
# 39           6           Poor        American Food
# 46         131           Good               Eatery
# 48          12        Average               Eatery
# 49          14        Average  Asian/European Food
# 50          92           Good        American Food
# 53         141           Good               Eatery
# 59           5      Very Poor        American Food
# 60           5      Very Poor  Asian/European Food
# 62           4      Very Poor        American Food
# 63          12        Average        American Food
# 67           6           Poor        American Food
# 69           1      Very Poor        American Food
# 71           6           Poor        American Food
# 72          19        Average        American Food
# 75           3      Very Poor               Eatery
# 76          10           Poor               Eatery
# 77           0      Very Poor               Eatery
# 79           1      Very Poor               Eatery
# 80           4      Very Poor               Eatery
# 83           6           Poor        American Food
# 84           7           Poor               Eatery
# 85           9           Poor               Eatery
# 87           8           Poor               Eatery
# 88           2      Very Poor               Eatery
# 89           5      Very Poor               Eatery
# 95           0      Very Poor               Eatery
# 98          14        Average               Eatery

# %% [markdown]
#  ### 3. Creating Clusters
#
# Now we need to apply K-Means for clustering.
# For that we need restaurant names , rated category and restaurant category.

# %%
# lets filter out required data in a different dataframe i.e. lable_df

columns = ['venue.name','Rated Category','Restaurant Category']
label_df = newyork_venues_df.loc[:,columns]
label_df.head()
# Out:
#             venue.name Rated Category  Restaurant Category
# 1  Carrot Top Pastries           Good               Eatery
# 2           Las Palmas           Good        American Food
# 7           Tasty Deli           Good               Eatery
# 8              Rain II        Average  Asian/European Food
# 9        Mike's Bagels           Good               Eatery

# %%
# Let's create dummy variables for 'Rated Category' and 'Restaurant Category'

label_dummies_df = pd.get_dummies(data = label_df , columns= ['Rated Category','Restaurant Category'])
label_dummies_df.head()
# Out:
#             venue.name  Rated Category_Average  Rated Category_Good  \
# 1  Carrot Top Pastries                       0                    1
# 2           Las Palmas                       0                    1
# 7           Tasty Deli                       0                    1
# 8              Rain II                       1                    0
# 9        Mike's Bagels                       0                    1
#
#    Rated Category_Poor  Rated Category_Very Poor  \
# 1                    0                         0
# 2                    0                         0
# 7                    0                         0
# 8                    0                         0
# 9                    0                         0
#
#    Restaurant Category_American Food  Restaurant Category_Asian/European Food  \
# 1                                  0                                        0
# 2                                  1                                        0
# 7                                  0                                        0
# 8                                  0                                        1
# 9                                  0                                        0
#
#    Restaurant Category_Eatery
# 1                           1
# 2                           0
# 7                           1
# 8                           0
# 9                           1

# %%
## Now, to get labels , run K-Means algorithm on above dataframe.

## let drop 'venue.name' column and apply KMeans on remaining data where number of cluster is 4.

cluster_label_df = label_dummies_df.drop('venue.name',axis=1)


k_means = KMeans(n_clusters=4,random_state=0).fit(cluster_label_df)
k_means.labels_
# Out:
# array([1, 0, 1, 2, 1, 1, 2, 2, 1, 0, 2, 0, 0, 1, 0, 0, 0, 1, 1, 2, 0, 1,
#        0, 2, 0, 0, 0, 0, 0, 0, 3, 1, 3, 3, 3, 0, 1, 1, 1, 3, 3, 3, 1])

# %%
#Now lets add these cluster labels to original dataframe i.e. newyork_venues_df

newyork_venues_df['Cluster Label'] = k_means.labels_
newyork_venues_df
# Out:
# C:\Users\akshay.nagar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                           venue.name           venue.categories  \
# 1                Carrot Top Pastries                     Bakery
# 2                         Las Palmas         Mexican Restaurant
# 7                         Tasty Deli             Sandwich Place
# 8                            Rain II            Thai Restaurant
# 9                      Mike's Bagels                 Bagel Shop
# 11                 Sweet Life Pastry                     Bakery
# 13      Antika Restaurant & Pizzeria         Italian Restaurant
# 14                           GoGo-Gi          Korean Restaurant
# 17                     Koronet Pizza                Pizza Place
# 20               La Barca Restaurant  Latin American Restaurant
# 22        Tung Thong Thai Restaurant            Thai Restaurant
# 23                        El Malecon  Latin American Restaurant
# 24           La Reina del Chicharron  Latin American Restaurant
# 26                Taszo Espresso Bar                Coffee Shop
# 35                        Wahi Diner                      Diner
# 36       Tropical Spanish Restaurant  Latin American Restaurant
# 39                      El Pitallito         Mexican Restaurant
# 46                        Dallas BBQ                  BBQ Joint
# 48                   Famous Famiglia                Pizza Place
# 49                        AquaMarina         Italian Restaurant
# 50            Chipotle Mexican Grill         Mexican Restaurant
# 53                         Starbucks                Coffee Shop
# 59               El Capri Restaurant  Latin American Restaurant
# 60  Silver Palace Chinese Restaurant         Chinese Restaurant
# 62                   Tu Sabor Latino  Latin American Restaurant
# 63              La Fiesta Restaurant         Mexican Restaurant
# 67                         Terravita    New American Restaurant
# 69             Windows On The Hudson    New American Restaurant
# 71              Blue Corn Restaurant         Mexican Restaurant
# 72           Restaurante La Libertad  Latin American Restaurant
# 75                 Subway Sandwiches             Sandwich Place
# 76              Little Caesars Pizza                Pizza Place
# 77                           Subways             Sandwich Place
# 79                            Subway             Sandwich Place
# 80              Little Caesars Pizza                Pizza Place
# 83   El Guanaco Restaurant Pupuseria  Latin American Restaurant
# 84                  Flaco's Pizzeria                Pizza Place
# 85                           Dunkin'                 Donut Shop
# 87         Floridita Broadway Bakery                     Bakery
# 88                 Subway Sandwiches             Sandwich Place
# 89                           Dunkin'                 Donut Shop
# 95                    Domino's Pizza                Pizza Place
# 98                           Dunkin'                 Donut Shop
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 1   4b2ce776f964a5208fca24e3           40.838933          -73.941359
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 7   4af0c188f964a520e2de21e3           40.841818          -73.939296
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 9   4b54f0d8f964a52043d427e3           40.841304          -73.939691
# 11  519baeaf498e8296a5d7134a           40.837456          -73.942427
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 17  5092a9e2e4b0487f2a8da22d           40.844232          -73.938979
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 26  5100025b19a9b90e8753b186           40.834465          -73.945274
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 46  4b0f0881f964a5205f5e23e3           40.839860          -73.940509
# 48  4bcfc9ceb221c9b6e3c9d2d0           40.841334          -73.939577
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 53  4b25a38bf964a520dc7424e3           40.841188          -73.939843
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 75  4c1ba521eac020a1382d45c2           40.844379          -73.937298
# 76  4c3cffbcb36ac92885e90486           40.846474          -73.935891
# 77  563ee2e4cd10872628b2cf66           40.842867          -73.941951
# 79  4e4ce4d1bd413c4cc66d0562           40.835914          -73.939998
# 80  5116f344e4b05931e1b2b529           40.835715          -73.943673
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
# 84  4bd1fe1bcaff9521c5d0d1f0           40.837052          -73.942743
# 85  56c4caa4cd101c2ccd5f6ff5           40.830994          -73.941094
# 87  4bc33a67461576b0574d7e32           40.847781          -73.937851
# 88  4c64998bdddfa593081492ff           40.834613          -73.944714
# 89  56a937bb498e8b18ac5e28e0           40.833955          -73.941003
# 95  589e949bc0c89b31d22f7e3d           40.833944          -73.941536
# 98  4c768e47d8948cfac3b56ada           40.835774          -73.944020
#
#     Like Count Rated Category  Restaurant Category  Cluster Label
# 1           62           Good               Eatery              1
# 2           47           Good        American Food              0
# 7           47           Good               Eatery              1
# 8           18        Average  Asian/European Food              2
# 9           49           Good               Eatery              1
# 11          15        Average               Eatery              1
# 13          63           Good  Asian/European Food              2
# 14          33        Average  Asian/European Food              2
# 17          46        Average               Eatery              1
# 20           7           Poor        American Food              0
# 22          34        Average  Asian/European Food              2
# 23         230           Good        American Food              0
# 24           9           Poor        American Food              0
# 26         198           Good               Eatery              1
# 35          72           Good        American Food              0
# 36          13        Average        American Food              0
# 39           6           Poor        American Food              0
# 46         131           Good               Eatery              1
# 48          12        Average               Eatery              1
# 49          14        Average  Asian/European Food              2
# 50          92           Good        American Food              0
# 53         141           Good               Eatery              1
# 59           5      Very Poor        American Food              0
# 60           5      Very Poor  Asian/European Food              2
# 62           4      Very Poor        American Food              0
# 63          12        Average        American Food              0
# 67           6           Poor        American Food              0
# 69           1      Very Poor        American Food              0
# 71           6           Poor        American Food              0
# 72          19        Average        American Food              0
# 75           3      Very Poor               Eatery              3
# 76          10           Poor               Eatery              1
# 77           0      Very Poor               Eatery              3
# 79           1      Very Poor               Eatery              3
# 80           4      Very Poor               Eatery              3
# 83           6           Poor        American Food              0
# 84           7           Poor               Eatery              1
# 85           9           Poor               Eatery              1
# 87           8           Poor               Eatery              1
# 88           2      Very Poor               Eatery              3
# 89           5      Very Poor               Eatery              3
# 95           0      Very Poor               Eatery              3
# 98          14        Average               Eatery              1

# %% [markdown]
# Now that we have different cluster,let's see on NY City map.

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)


x = np.arange(4)
ys = [i+x+(i*x)**2 for i in range(4)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


markers_colors = []
for lat, lon, poi, cluster in zip(newyork_venues_df['venue.location.lat'], newyork_venues_df['venue.location.lng'], newyork_venues_df['venue.name'], newyork_venues_df['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looks Beautiful right !!

# %% [markdown]
# ### 4. Examine Clusters

# %% [markdown]
# ##### Cluster 1
#
# Characteristics:
#     1. Mostly Eateries.
#     2. We can get Good food here.

# %%
cluster1_df = newyork_venues_df.loc[newyork_venues_df['Cluster Label'] == 0]
cluster1_df
# Out:
#                          venue.name           venue.categories  \
# 2                        Las Palmas         Mexican Restaurant
# 20              La Barca Restaurant  Latin American Restaurant
# 23                       El Malecon  Latin American Restaurant
# 24          La Reina del Chicharron  Latin American Restaurant
# 35                       Wahi Diner                      Diner
# 36      Tropical Spanish Restaurant  Latin American Restaurant
# 39                     El Pitallito         Mexican Restaurant
# 50           Chipotle Mexican Grill         Mexican Restaurant
# 59              El Capri Restaurant  Latin American Restaurant
# 62                  Tu Sabor Latino  Latin American Restaurant
# 63             La Fiesta Restaurant         Mexican Restaurant
# 67                        Terravita    New American Restaurant
# 69            Windows On The Hudson    New American Restaurant
# 71             Blue Corn Restaurant         Mexican Restaurant
# 72          Restaurante La Libertad  Latin American Restaurant
# 83  El Guanaco Restaurant Pupuseria  Latin American Restaurant
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 2   4b68d051f964a520518e2be3           40.837575          -73.942351
# 20  4b1a328df964a52016e823e3           40.837515          -73.942312
# 23  4a2eb22df964a52035981fe3           40.846274          -73.938535
# 24  4c69e8d61a6620a138f0648c           40.843790          -73.937806
# 35  51cf1616498e45e34e0176d4           40.838438          -73.941791
# 36  4ca73d06b7106dcb6fb065a5           40.833988          -73.945202
# 39  540b3d8e498e9d0f44c1ae8b           40.836399          -73.943083
# 50  51b7552a498e828e1adbae94           40.841501          -73.939876
# 59  4bedb6b1767dc9b6045cd3e9           40.846680          -73.935487
# 62  4e164538ae60de5d28f164f8           40.836682          -73.943030
# 63  4ba98891f964a520022d3ae3           40.834529          -73.944853
# 67  5b57bb361acf11002c14ba96           40.848059          -73.937645
# 69  4bc39ff1abf49521bb0ac493           40.842016          -73.943241
# 71  4bd4e92f6798ef3be5ae628d           40.833263          -73.941743
# 72  50f304d9e4b0f8af24e65379           40.833554          -73.945118
# 83  4debcfd645dd3993a8af6691           40.848133          -73.937704
#
#     Like Count Rated Category Restaurant Category  Cluster Label
# 2           47           Good       American Food              0
# 20           7           Poor       American Food              0
# 23         230           Good       American Food              0
# 24           9           Poor       American Food              0
# 35          72           Good       American Food              0
# 36          13        Average       American Food              0
# 39           6           Poor       American Food              0
# 50          92           Good       American Food              0
# 59           5      Very Poor       American Food              0
# 62           4      Very Poor       American Food              0
# 63          12        Average       American Food              0
# 67           6           Poor       American Food              0
# 69           1      Very Poor       American Food              0
# 71           6           Poor       American Food              0
# 72          19        Average       American Food              0
# 83           6           Poor       American Food              0

# %% [markdown]
# ##### Cluster 2
#
# Characteristics:
#     1. Mostly American
#     2. Food quality is below average

# %%
cluster2_df = newyork_venues_df.loc[newyork_venues_df['Cluster Label'] == 1]
cluster2_df
# Out:
#                    venue.name venue.categories                  venue.id  \
# 1         Carrot Top Pastries           Bakery  4b2ce776f964a5208fca24e3
# 7                  Tasty Deli   Sandwich Place  4af0c188f964a520e2de21e3
# 9               Mike's Bagels       Bagel Shop  4b54f0d8f964a52043d427e3
# 11          Sweet Life Pastry           Bakery  519baeaf498e8296a5d7134a
# 17              Koronet Pizza      Pizza Place  5092a9e2e4b0487f2a8da22d
# 26         Taszo Espresso Bar      Coffee Shop  5100025b19a9b90e8753b186
# 46                 Dallas BBQ        BBQ Joint  4b0f0881f964a5205f5e23e3
# 48            Famous Famiglia      Pizza Place  4bcfc9ceb221c9b6e3c9d2d0
# 53                  Starbucks      Coffee Shop  4b25a38bf964a520dc7424e3
# 76       Little Caesars Pizza      Pizza Place  4c3cffbcb36ac92885e90486
# 84           Flaco's Pizzeria      Pizza Place  4bd1fe1bcaff9521c5d0d1f0
# 85                    Dunkin'       Donut Shop  56c4caa4cd101c2ccd5f6ff5
# 87  Floridita Broadway Bakery           Bakery  4bc33a67461576b0574d7e32
# 98                    Dunkin'       Donut Shop  4c768e47d8948cfac3b56ada
#
#     venue.location.lat  venue.location.lng  Like Count Rated Category  \
# 1            40.838933          -73.941359          62           Good
# 7            40.841818          -73.939296          47           Good
# 9            40.841304          -73.939691          49           Good
# 11           40.837456          -73.942427          15        Average
# 17           40.844232          -73.938979          46        Average
# 26           40.834465          -73.945274         198           Good
# 46           40.839860          -73.940509         131           Good
# 48           40.841334          -73.939577          12        Average
# 53           40.841188          -73.939843         141           Good
# 76           40.846474          -73.935891          10           Poor
# 84           40.837052          -73.942743           7           Poor
# 85           40.830994          -73.941094           9           Poor
# 87           40.847781          -73.937851           8           Poor
# 98           40.835774          -73.944020          14        Average
#
#    Restaurant Category  Cluster Label
# 1               Eatery              1
# 7               Eatery              1
# 9               Eatery              1
# 11              Eatery              1
# 17              Eatery              1
# 26              Eatery              1
# 46              Eatery              1
# 48              Eatery              1
# 53              Eatery              1
# 76              Eatery              1
# 84              Eatery              1
# 85              Eatery              1
# 87              Eatery              1
# 98              Eatery              1

# %% [markdown]
# ##### Cluster 3
#
# Characteristics:
#     1. Mostly Asian/European Food.
#     2. Most of the restaurants have average food quality.

# %%
cluster3_df = newyork_venues_df.loc[newyork_venues_df['Cluster Label'] == 2]
cluster3_df
# Out:
#                           venue.name    venue.categories  \
# 8                            Rain II     Thai Restaurant
# 13      Antika Restaurant & Pizzeria  Italian Restaurant
# 14                           GoGo-Gi   Korean Restaurant
# 22        Tung Thong Thai Restaurant     Thai Restaurant
# 49                        AquaMarina  Italian Restaurant
# 60  Silver Palace Chinese Restaurant  Chinese Restaurant
#
#                     venue.id  venue.location.lat  venue.location.lng  \
# 8   53f045ba498ec9e735cd769d           40.838368          -73.939900
# 13  4cfe75a2feec6dcb0d1b5836           40.838778          -73.941210
# 14  4ba26242f964a5207cf337e3           40.838098          -73.941941
# 22  523c757f11d2bbf1b13f0aee           40.841451          -73.938856
# 49  4b75e189f964a520b72b2ee3           40.843199          -73.939169
# 60  4e4cd2babd413c4cc66c7241           40.836006          -73.943342
#
#     Like Count Rated Category  Restaurant Category  Cluster Label
# 8           18        Average  Asian/European Food              2
# 13          63           Good  Asian/European Food              2
# 14          33        Average  Asian/European Food              2
# 22          34        Average  Asian/European Food              2
# 49          14        Average  Asian/European Food              2
# 60           5      Very Poor  Asian/European Food              2

# %% [markdown]
# ##### Cluster 4
#
# Characteristics:
#     1. Mostly Eateries.
#     2. I won't recommend these places as they have poor ratings.

# %%
cluster4_df = newyork_venues_df.loc[newyork_venues_df['Cluster Label'] == 3]
cluster4_df
# Out:
#               venue.name venue.categories                  venue.id  \
# 75     Subway Sandwiches   Sandwich Place  4c1ba521eac020a1382d45c2
# 77               Subways   Sandwich Place  563ee2e4cd10872628b2cf66
# 79                Subway   Sandwich Place  4e4ce4d1bd413c4cc66d0562
# 80  Little Caesars Pizza      Pizza Place  5116f344e4b05931e1b2b529
# 88     Subway Sandwiches   Sandwich Place  4c64998bdddfa593081492ff
# 89               Dunkin'       Donut Shop  56a937bb498e8b18ac5e28e0
# 95        Domino's Pizza      Pizza Place  589e949bc0c89b31d22f7e3d
#
#     venue.location.lat  venue.location.lng  Like Count Rated Category  \
# 75           40.844379          -73.937298           3      Very Poor
# 77           40.842867          -73.941951           0      Very Poor
# 79           40.835914          -73.939998           1      Very Poor
# 80           40.835715          -73.943673           4      Very Poor
# 88           40.834613          -73.944714           2      Very Poor
# 89           40.833955          -73.941003           5      Very Poor
# 95           40.833944          -73.941536           0      Very Poor
#
#    Restaurant Category  Cluster Label
# 75              Eatery              3
# 77              Eatery              3
# 79              Eatery              3
# 80              Eatery              3
# 88              Eatery              3
# 89              Eatery              3
# 95              Eatery              3

# %% [markdown]
# ## End of Notebook
